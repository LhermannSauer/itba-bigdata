# %%
from pyspark.sql import SparkSession


def get_spark(app_name: str = "LocalSparkApp", memory: str = "4g") -> SparkSession:
    spark = (
        SparkSession.builder
        .appName(app_name)
        .master("local[*]")  # run locally on all cores
        .config("spark.sql.shuffle.partitions", "4")
        .config("spark.driver.memory", memory)
        .config("spark.sql.execution.arrow.pyspark.enabled", "true")
        .getOrCreate()
    )

    spark.sparkContext.setLogLevel("WARN")
    return spark

# %%
GOLD_PATH = '../data/gold/sentiment/amazon_reviews_furniture/sentiment.parquet/'
spark = get_spark()
df = spark.read.parquet(GOLD_PATH)
df.printSchema()

df.show(4)
# Out:
# root
#  |-- review_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- clean_text: string (nullable = true)
#  |-- sentiment_label: string (nullable = true)
#  |-- star_rating: integer (nullable = true)
#  |-- review_date: date (nullable = true)
#  |-- helpful_votes: integer (nullable = true)
#  |-- total_votes: integer (nullable = true)
#  |-- verified_purchase: boolean (nullable = true)
# +--------------+----------+-----------+--------------+---------------+-----------+-----------+-------------+-----------+-----------------+
# |     review_id|product_id|customer_id|    clean_text|sentiment_label|star_rating|review_date|helpful_votes|total_votes|verified_purchase|
# +--------------+----------+-----------+--------------+---------------+-----------+-----------+-------------+-----------+-----------------+
# |R1000UH76TCSZS|B0018SNGN6|   49258507| < >< > < >< >|       negative|          1| 2013-05-22|            6|          7|             true|
# |R1001RHHXA22JP|B003CT37JM|   19021547|          2000|       positive|          5| 2013-12-15|            0|          0|             true|
# |R1003SLTXJKZ3S|B0017LULLE|   41065803|              |       positive|          5| 2014-04-07|            2|          3|             true|
# |R1004C6IRFDVST|B008B7Q8VY|   40649674|5 25 x 7 5 3 x|       negative|          1| 2013-05-30|            1|          1|             true|
# +--------------+----------+-----------+--------------+---------------+-----------+-----------+-------------+-----------+-----------------+
# only showing top 4 rows
